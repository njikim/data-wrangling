# %%
import numpy as np
import pandas as pd

# %%
import glob

path = r'C:/Python/movie-data-analysis/data/movie' 
all_files = glob.glob(path + "/*.csv")
print(all_files)
# li = []
# for filename in all_files:
#     df = pd.read_excel(filename)
#     li.append(df)

# #frame = pd.concat(li, axis=0, ignore_index=True)
# Out:
# []

# %%
li
# Out:
# []

# %%
year_2018 = pd.read_excel('C:/Python/movie-data-analysis/data/movie/2010_box.xlsx')

# %%
year_2018
# Out:
#         순위               영화명        개봉일          매출액     매출액        누적매출액   \
# 0      NaN               NaN        NaT           NaN   점유율            NaN
# 1        1               아바타 2009-12-17  8.145573e+10   0.07  1.248969e+11
# 2        2               아저씨 2010-08-04  4.710133e+10  0.041  4.710133e+10
# 3        3               인셉션 2010-07-21  4.339499e+10  0.037  4.339499e+10
# 4        4               의형제 2010-02-04  4.015373e+10  0.035  4.015373e+10
# 5        5            아이언맨 2 2010-04-29  3.263520e+10  0.028  3.263520e+10
# 6        6               전우치 2009-12-23  2.634511e+10  0.023  4.409272e+10
# 7        7                이끼 2010-07-14  2.543730e+10  0.022  2.543730e+10
# 8        8             포화속으로 2010-06-16  2.383196e+10  0.021  2.383196e+10
# 9        9               하모니 2010-01-28  2.164175e+10  0.019  2.164175e+10
# 10      10               방자전 2010-06-02  2.249002e+10  0.019  2.249002e+10
# ...
