# %%
import numpy as np
import pandas as pd

# %%
# 영진위 박스오피스 연도별 2018
year_2018 = pd.read_excel('C:/Python/movie-data-analysis/data/연도별_2018_box.xlsx', skiprows=[0,1,2,3])
year_2018
# Out:
#         순위                     영화명        개봉일            매출액  매출액 점유율  \
# 0        1               신과함께-인과 연 2018-08-01   102666146909    0.057
# 1        2            어벤져스: 인피니티 워 2018-04-25    99926399769    0.055
# 2        3                보헤미안 랩소디 2018-10-31    80010440345    0.044
# 3        4            미션 임파서블: 폴아웃 2018-07-25    55888375112    0.031
# 4        5               신과함께-죄와 벌 2017-12-20    47355583705    0.026
# 5        6           쥬라기 월드: 폴른 킹덤 2018-06-06    49770711037    0.027
# 6        7                앤트맨과 와스프 2018-07-04    47468053685    0.026
# 7        8                     안시성 2018-09-19    46335334026    0.026
# 8        9                   블랙 팬서 2018-02-14    45885123957    0.025
# 9       10                  완벽한 타인 2018-10-31    44350807074    0.024
# 10      11                    1987 2017-12-27    42915772108    0.024
# 11      12                      독전 2018-05-22    43485551113    0.024
# ...

# %%
# 영진위 박스오피스 기간별 2018.01.01~2018.12.31
duration_2018 = pd.read_excel('C:/Python/movie-data-analysis/data/기간별_2018_box.xlsx', skiprows=[0,1,2,3,5])
duration_2018
# Out:
#         순위                          영화명        개봉일           매출액     매출액  \
# 0        1                    신과함께-인과 연 2018-08-01   102666146909  0.057
# 1        2                 어벤져스: 인피니티 워 2018-04-25    99926399769  0.055
# 2        3                     보헤미안 랩소디 2018-10-31    80010440345  0.044
# 3        4                 미션 임파서블: 폴아웃 2018-07-25    55888375112  0.031
# 4        5                    신과함께-죄와 벌 2017-12-20    47355583705  0.026
# 5        6                쥬라기 월드: 폴른 킹덤 2018-06-06    49770711037  0.027
# 6        7                     앤트맨과 와스프 2018-07-04    47468053685  0.026
# 7        8                          안시성 2018-09-19    46335334026  0.026
# 8        9                        블랙 팬서 2018-02-14    45885123957  0.025
# 9       10                       완벽한 타인 2018-10-31    44350807074  0.024
# 10      11                         1987 2017-12-27    42915772108  0.024
# 11      12                           독전 2018-05-22    43485551113  0.024
# ...

# %% [markdown]
# #### duration_2018 column명 불필요한 space 제거

# %%
duration_2018.columns
# Out:
# Index(['순위', '영화명', '개봉일', '매출액 ', '매출액', '누적매출액 ', '관객수 ', '누적관객수 ', '스크린수 ',
#        '상영횟수 ', '대표국적 ', '국적 ', '제작사 ', '배급사 ', '등급 ', '장르 ', '감독 ', '배우 '],
#       dtype='object')

# %%
duration_2018.columns = ['순위', '영화명', '개봉일', '매출액 ', '매출액 점유율', '누적매출액', '관객수', '누적관객수', '스크린수',
       '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우']

# %%
year_2018.columns
# Out:
# Index(['순위', '영화명', '개봉일', '매출액', '매출액 점유율', '관객수', '스크린수', '상영횟수', '대표국적',
#        '국적', '배급사'],
#       dtype='object')

# %% [markdown]
# #### year_2018 상위 200 (박스오피스 연도별 상위 200)

# %%
year_2018_200 = year_2018[:200]
year_2018_200
# Out:
#       순위                    영화명        개봉일           매출액  매출액 점유율       관객수  \
# 0      1              신과함께-인과 연 2018-08-01  102666146909    0.057  12274996
# 1      2           어벤져스: 인피니티 워 2018-04-25   99926399769    0.055  11212710
# 2      3               보헤미안 랩소디 2018-10-31   80010440345    0.044   9224582
# 3      4           미션 임파서블: 폴아웃 2018-07-25   55888375112    0.031   6584915
# 4      5              신과함께-죄와 벌 2017-12-20   47355583705    0.026   5872007
# 5      6          쥬라기 월드: 폴른 킹덤 2018-06-06   49770711037    0.027   5661128
# 6      7               앤트맨과 와스프 2018-07-04   47468053685    0.026   5448134
# 7      8                    안시성 2018-09-19   46335334026    0.026   5440186
# 8      9                  블랙 팬서 2018-02-14   45885123957    0.025   5399227
# 9     10                 완벽한 타인 2018-10-31   44350807074    0.024   5293435
# 10    11                   1987 2017-12-27   42915772108    0.024   5290310
# ...

# %% [markdown]
# #### 기간별 박스오피스에서 필요한 컬럼만 뽑기

# %%
duration_2018 = duration_2018[['영화명', '제작사', '배급사', '등급', '장르', '감독', '배우']]
duration_2018
# Out:
#                               영화명                            제작사  \
# 0                       신과함께-인과 연         리얼라이즈픽쳐스(주),(주)덱스터스튜디오
# 1                    어벤져스: 인피니티 워                            NaN
# 2                        보헤미안 랩소디                            NaN
# 3                    미션 임파서블: 폴아웃                      파라마운트 픽쳐스
# 4                       신과함께-죄와 벌         리얼라이즈픽쳐스(주),(주)덱스터스튜디오
# 5                   쥬라기 월드: 폴른 킹덤                            NaN
# 6                        앤트맨과 와스프                            NaN
# 7                             안시성   (주)영화사수작,(주)스튜디오앤뉴,주식회사 모티브랩
# 8                           블랙 팬서                            NaN
# 9                          완벽한 타인             (주)필름몬스터,드라마하우스(주)
# 10                           1987                        (주)우정필름
# 11                             독전                         (주)용필름
# 12                             공작            (주)영화사 월광,(주)사나이픽처스
# ...

# %% [markdown]
# #### 기간별 + 연도별 박스오피스 컬럼 합치기

# %%
year_2018_200_selected = pd.merge(year_2018_200, duration_2018, how="left")
year_2018_200_selected
# Out:
#       순위                    영화명        개봉일           매출액  매출액 점유율       관객수  \
# 0      1              신과함께-인과 연 2018-08-01  102666146909    0.057  12274996
# 1      2           어벤져스: 인피니티 워 2018-04-25   99926399769    0.055  11212710
# 2      3               보헤미안 랩소디 2018-10-31   80010440345    0.044   9224582
# 3      4           미션 임파서블: 폴아웃 2018-07-25   55888375112    0.031   6584915
# 4      5              신과함께-죄와 벌 2017-12-20   47355583705    0.026   5872007
# 5      6          쥬라기 월드: 폴른 킹덤 2018-06-06   49770711037    0.027   5661128
# 6      7               앤트맨과 와스프 2018-07-04   47468053685    0.026   5448134
# 7      8                    안시성 2018-09-19   46335334026    0.026   5440186
# 8      9                  블랙 팬서 2018-02-14   45885123957    0.025   5399227
# 9     10                 완벽한 타인 2018-10-31   44350807074    0.024   5293435
# 10    11                   1987 2017-12-27   42915772108    0.024   5290310
# ...

# %%
year_2018_200_selected.isna().sum()
# Out:
# 순위           0
# 영화명          0
# 개봉일          0
# 매출액          0
# 매출액 점유율      0
# 관객수          0
# 스크린수         0
# 상영횟수         0
# 대표국적         0
# 국적           0
# 배급사          1
# 제작사        123
# 등급           0
# 장르           0
# 감독           1
# 배우           9
# dtype: int64

# %%
genre = year_2018_200_selected['장르'].unique()
genre
# Out:
# array(['판타지,드라마', '액션,어드벤처,판타지,SF', '드라마', '액션,스릴러', '액션,어드벤처,SF',
#        '사극,액션', '액션,드라마,SF', '드라마,코미디', '범죄,액션', '액션,SF,스릴러', '범죄,드라마',
#        '액션,어드벤처,코미디,SF', '애니메이션', '액션', '코미디,드라마', '미스터리,액션', '코미디,범죄',
#        '애니메이션,액션,어드벤처,코미디,가족', '멜로/로맨스', '공포(호러),스릴러', '스릴러',
#        '사극,어드벤처,코미디', '판타지', '뮤지컬', '액션,SF,어드벤처', '사극', '범죄', '액션,어드벤처',
#        '스릴러,드라마', '액션,범죄', '코미디', '애니메이션,코미디,가족,판타지', '공포(호러)',
#        '액션,어드벤처,범죄', 'SF,액션', '액션,사극', '애니메이션,판타지,어드벤처', 'SF,드라마',
#        '애니메이션,액션,가족', '드라마,뮤지컬', '공포(호러),미스터리,스릴러', '다큐멘터리',
#        '애니메이션,어드벤처,코미디', '미스터리', '액션,공포(호러),SF', '공포(호러),스릴러,드라마',
#        '어드벤처,판타지', '어드벤처', '애니메이션,코미디', '드라마,멜로/로맨스', '코미디,드라마,범죄',
#        '액션,드라마', '애니메이션,가족', '기타', '가족,판타지', '액션,코미디', '액션,범죄,드라마',
#        '멜로/로맨스,스릴러', '액션,드라마,전쟁', '드라마,멜로/로맨스,스릴러', '공포(호러),미스터리',
#        '판타지,공포(호러),미스터리,SF,스릴러', '액션,SF', '애니메이션,SF,어드벤처', 'SF,액션,스릴러',
#        '멜로/로맨스,코미디', '미스터리,범죄,스릴러', '드라마,스릴러', '스릴러,미스터리', '범죄,코미디',
# ...

# %% [markdown]
# #### 유니크 장르 list 생성

# %%
genre_unique = []
for i in range(len(genre)):
    for j in range(len(genre[i].split(','))):
        if genre[i].split(',')[j] not in genre_unique:
            genre_unique.append(genre[i].split(',')[j])

# %%
genre_unique
# Out:
# ['판타지',
#  '드라마',
#  '액션',
#  '어드벤처',
#  'SF',
#  '스릴러',
#  '사극',
#  '코미디',
#  '범죄',
#  '애니메이션',
#  '미스터리',
#  '가족',
#  '멜로/로맨스',
#  '공포(호러)',
#  '뮤지컬',
#  '다큐멘터리',
#  '기타',
#  '전쟁']

# %%
year_2018_200_selected['장르'][1]
# Out:
# '액션,어드벤처,판타지,SF'

# %% [markdown]
# #### 장르별 sorting 예시 (코미디)

# %%
lst = []
for i in range(201):
    if '코미디' in year_2018_200_selected['장르'][i]:
        lst.append(year_2018_200_selected['영화명'][i])
lst
# Out:
# ['완벽한 타인',
#  '데드풀 2',
#  '그것만이 내 세상',
#  '탐정: 리턴즈',
#  '인크레더블 2',
#  '조선명탐정: 흡혈괴마의 비밀',
#  '궁합',
#  '바람 바람 바람',
#  '몬스터 호텔 3',
#  '염력',
#  '레슬러',
#  '페르디난드',
#  '그린치',
#  '원더풀 고스트',
#  '패딩턴 2',
#  '나를 차버린 스파이',
#  '아이 필 프리티',
#  '크레이지 리치 아시안',
#  '다운사이징',
#  '레이디 버드',
#  '게이트',
#  '쓰리 빌보드',
#  '베일리 어게인',
#  '셜록 놈즈',
#  '비밥바룰라',
#  '배반의 장미']

# %% [markdown]
# #### top3

# %%
lst[:3]
# Out:
# ['완벽한 타인', '데드풀 2', '그것만이 내 세상']
